# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load encoded dataset from Day 9
df = pd.read_csv("../data/encoded_churn.csv")

# Separate features and target
X = df.drop("Churn", axis=1)
y = df["Churn"]

print("\nTOTAL DATA SHAPE:")
print(df.shape)

# Train-test split (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("\nTRAINING SET SHAPE:")
print(X_train.shape)

print("\nTESTING SET SHAPE:")
print(X_test.shape)

print("\nDAY 10 COMPLETED: Train-test split successful")
# Out:
# TOTAL DATA SHAPE:
# (7043, 7076)
#
# TRAINING SET SHAPE:
# (5634, 7075)
#
# TESTING SET SHAPE:
# (1409, 7075)
#
# DAY 10 COMPLETED: Train-test split successful
